# %% [markdown]
# Suppose, We're in a situation to create a Sentiment analysis model, we have the dataset available but the problem here is machine will not going to understand the sentences of any languages, we have to clean those dataset by using stopwords, deleting punctuation and many more irrelevant things inside the data and We have to make it upto that level where we can feed those data to our machine or deep learning algorithms from that we can get some output with it.
#
# We are assuming you have a knowledge of Python, and if not, nothing to worry, we will give you some overview of it.
#
# #### Python String
# A String is like a sequence of Characters.
#
# A character is just a symbol. Like, the English language has 26 characters.
#
# Computers don't deal with characters, they deal with binary(numbers) only. Even though you seen characters but internally it is stored and manipulated with the combination of 0's and 1's. The conversion of character to a number is known as encoding, and the reverse is decoding.
#
# String literally surrounded by a single or double quotations like:

# %%
a = "DATa"
print(a)
# Out:
# DATa

# %% [markdown]
# ## Strings are arrays
#
# Like in other popular programming languages, strings in Python are arrays of bytes represents unicode characters.
#
# However, Python doesn't have the character as the datatype, single character is just simply a string with length of 1.
#
# We used square bracket to access elements from the string.

# %%
# Get the character at position 4 (Here, indexing starts from 0)
a = "DATASET"
print(a[4])  # Output: S
# Out:
# S

# %% [markdown]
# ## Slicing
#
# You can get the output upto certain range of characters by using the slicing index.
#
# Specify the start index and end index, which is separated by colon, to return a part of the string.

# %%
# To get the output from the position 3 to 6(not included)
a = "Data test"
print(a[3:6])

print("-" * 50)  # This line prints 50 dashes

# To get the output by negative indexing from 6 position to 2 position.
print(a[-6:-2])

print("-" * 50)  # This line prints 50 dashes

# Get the results from position 2 to 6 but give result with the increment of 2.
print(a[2:6:2])
# Out:
# a t
# --------------------------------------------------
# a te
# --------------------------------------------------
# t

# %% [markdown]
# # String Methods
#
# Python has a set of built-in methods that you can use on strings.

# %%
#lower() will lowercase the words which are upper in the sentences.
a = "data test"
print(a.lower())
# Out:
# data test

# %%
#upper() will transform lowercase into upper.
print(a.upper())
# Out:
# DATA TEST

# %%
#replace() will work like replace one string with another string.
a = "data test"
print(a.replace("i", "me"))
# Out:
# data test

# %%
#split() will split the strings into substrings if it finds any instances of seprator.
a = "data test"

print(a.split("o"))
# Out:
# ['data test']

# %% [markdown]
# ## String Concatination
#
# Combine 2 string or more then 2 string using + symbol

# %%
b = "Train"
a = "data test"

print(a +" "+ b)
# Out:
# data test Train

# %% [markdown]
# # Import text
# In NLP your dataset would be in .txt, .csv type of format, you need to import it and try to clean the irrelevant datas from the dataset. Here'll going to understand Python file handling:create, open, read, append, write.
#
# # Create a text file
#
# With the use of python you can create the text files by using code, we have demostrated here how you can do this.

# %%
# Step 1
file = open("datatest.txt", "w+")

# Here we declared file as a variable to open a file named iNeuron.txt. Open takes two arguemnets, first one is for the file we want to open and second
# one represents some kind of permissions or operation we want to do into that file.

# Here we taken "W" letter as an arguemnt, which indicates write and will create a file if it is not exist in the library.
# That "+" signs indicate both read and write.

# The other option beside "w" are, "r" for read, and "a" for append.

# %% [markdown]
# ![image.png](attachment:6623126d-8f9c-44a5-b411-2ed7283d7209.png)

# %%
# Step 2
for i in range(5):
    file.write("Line number is %d\r\n" % (i + 1))

# %% [markdown]
# ![image.png](attachment:f93a3c97-5b65-4097-a6ab-e1e208c80804.png)

# %%
#Step 3

file.close()

# %% [markdown]
# ![image.png](attachment:4e9bf2d5-d07e-43e0-b402-a15b7bde94e4.png)

# %% [markdown]
# # Append data to a file
#
# You can also append a new text inside the existing file or in a new file.

# %%
 #Step1

file= open("datatest.txt", "a+")

# %% [markdown]
# Once again "+" sign is in the code which means if .txt file are not available, this plus sign will create a new file but here is not any requirement to create a new file.

# %%
#Step2

for i in range(3):
    file.write("Appending Line number %d\r\n" % (i+1))

# %% [markdown]
# This will write data into a file in append mode.

# %%
#Step3

file.close()

# %% [markdown]
# We seen earlier this close function will close the instance of the file iNeuron.txt stored.

# %% [markdown]
# # Read the files
#
# Not only you create .txt files in Python but you can also call .txt file in a "read mode"(r).

# %%
#Step1. Open the file in read mode

file= open("datatest.txt", "r")

# %%
#Step2. Here we'll check, is our file is open or not, if yes we proceed
if file.mode == 'r':               
    content=file.read() #We used file.read() for reading the file data and store it in a variable.

# %%
#Step3. Printing the file
print(content)
print("Here is the output!")
# Out:
# Line number is 1
# Line number is 2
# Line number is 3
# Line number is 4
# Line number is 5
# Appending Line number 1
# Appending Line number 2
# Appending Line number 3
#
# Here is the output!

# %% [markdown]
# ![image.png](attachment:6f40ce7f-eff1-4366-9957-c6bd99d034a6.png)

# %% [markdown]
# # Text Preprocessing
#
# Suppose we have textual data available, we need to apply many of pre-processing steps to the data to transform those words into numerical features that work with machine learning algorithms.
#
# The pre-processing steps for the problem depend mainly on the domain and the problem itself. We don't need to apply all the steps for every problem.
#
# Here, we're going to see text preprocessing in Python. We'll use NLTK(Natural language toolkit) library here.

# %%
#import necessary libraries
import nltk

import string
import re

# %%
#Text Lowercase
def lowercase_text(text):
    return text.lower()

input_str = "Weather is too Cloudy. Possibility of Rain is High, Today!!"
lowercase_text(input_str)
# Out:
# 'weather is too cloudy. possibility of rain is high, today!!'

# %%
#For Removing numbers

def remove_num(text):
    result = re.sub(r'\d+','', text)
    return result

# %%
input_s ="You bought 6 candies from shop, and 4 candies are in home."
remove_num(input_s)
# Out:
# 'You bought  candies from shop, and  candies are in home.'

# %% [markdown]
# As we mentioned above, you can also convert the numbers into words. This could be done by using the inflect library.

# %%
# !pip install inflect
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
# ...
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import inflect

# Initialize the inflect engine
p = inflect.engine()

# Convert number into text
def convert_num(text):
    # Split strings into list of texts
    temp_string = text.split()

    # Initialize empty list
    new_str = []

    for word in temp_string:
        # If text is a digit, convert the digit to words and append into the new str list
        if word.isdigit():
            new_str.append(p.number_to_words(word))
        # Append the texts as it is
        else:
            new_str.append(word)

    # Join the texts of new str to form a string
    temp_str = ' '.join(new_str)

    return temp_str

input_str = 'input = "shivam got 1 out of 100'
print(convert_num(input_str))
# Out:
# input = "shivam got one out of one hundred

# %% [markdown]
# # Remove punctuation.
# We remove punctuations because otherwise we don't have different forms of the same word. If we don't remove punctuations, then 'been', 'been', and 'been!' will be treated separately.

# %%
#Let's remove punctuation
def rem_punct(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

# %%
input_str = "Hey, Are you excited??, After a week, we will be in Shimla!!!"
rem_punct(input_str)
# Out:
# 'Hey Are you excited After a week we will be in Shimla'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# # Remove default stopwords
#
# Stopwords are words that do not contribute to the meaning of the sentence. Hence, they can be safely removed without causing any change in the meaning of a sentence. The NLTK(Natural Language Toolkit) library has the set of stopwords and we can use these to remove stopwords from our text and return a list of word tokens.

# %%
#importing nltk library
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/tar-
# [nltk_data]     tt060-saurav/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/tar-
# [nltk_data]     tt060-saurav/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def remove_stopwords(text):
  """Removes stopwords from a text string.

  Args:
    text: The text string to remove stopwords from.

  Returns:
    A new text string with stopwords removed.
  """

  stop_words = set(stopwords.words("english"))  # Import stopwords from nltk library
  word_tokens = word_tokenize(text)  # Import word_tokenize from nltk library

  # Filter out punctuation and stopwords
  filtered_text = [word for word in word_tokens if word not in string.punctuation]
  filtered_text = [word for word in filtered_text if word not in stop_words]

  return filtered_text

# Example usage
text = "Data is the new oil. A.I is the last invention"
filtered_text = remove_stopwords(text)
print(filtered_text)
# Out:
# ['Data', 'new', 'oil', 'A.I', 'last', 'invention']

# %% [markdown]
# # Stemming
#
# From Stemming we will process of getting the root form of a word. Root or Stem is the part to which inflextional affixes(like -ed, -ize, etc) are added. We would create the stem words by removing the prefix of suffix of a word. So, stemming a word may not result in actual words.
#
# For Example: Mangoes ---> Mango
#
#
#              Boys --> Boy
#
#
#              Going --> go
#
#
# If our sentences are not in tokens, then we need to convert them into tokens. After we converted strings of text into tokens, then we can convert those word tokens into their root form. These are the Porter stemmer, the snowball stemmer, and the Lancaster Stemmer. We usually use Porter stemmer among them.

# %%
#importing nltk's porter stemmer
from nltk.stem.porter import PorterStemmer

from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()

#stem words in the list of tokenised words
def stem_words(text):
  word_tokens = word_tokenize(text)
  stems = [stemmer.stem(word) for word in word_tokens]
  return stems

text = 'Data is the new revolution in the World, in a day one individual would generate terabytes of data.'
stem_words(text)
# Out:
# ['data',
#  'is',
#  'the',
#  'new',
#  'revolut',
#  'in',
#  'the',
#  'world',
#  ',',
#  'in',
#  'a',
#  'day',
#  'one',
#  'individu',
#  'would',
#  'gener',
#  'terabyt',
#  'of',
#  'data',
#  '.']

# %% [markdown]
# # Lemmatization
#
# Lemmatization is a process in which words are reduced to their base or root form. For example, the lemma of the word "running" is "run." Lemmatization is similar to stemming, but it takes into account the part of speech of the word. This is important because some words can have different base forms depending on their part of speech. For example, the lemma of the word "play" is "play" as a verb, but "player" as a noun.

# %%
from nltk.stem import wordnet
from nltk.tokenize import word_tokenize

def lemmatize_word(text):
  """Lemmatizes the text string.

  Args:
    text: The text string to lemmatize.

  Returns:
    A list of lemmatized words.
  """
  # Download WordNet if not already downloaded
  nltk.download('wordnet')
  
  # Tokenize the text
  word_tokens = word_tokenize(text)
  
  # Lemmatize each word
  lemmas = [wordnet.WordNetLemmatizer().lemmatize(word, pos='v') for word in word_tokens]
  
  return lemmas

# Example usage
text = "Data is the new revolution in the World, in a day one individual would generate terabytes of data."
lemmatized_words = lemmatize_word(text)
print(lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to /home/tar-
# [nltk_data]     tt060-saurav/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['Data', 'be', 'the', 'new', 'revolution', 'in', 'the', 'World', ',', 'in', 'a', 'day', 'one', 'individual', 'would', 'generate', 'terabytes', 'of', 'data', '.']

# %% [markdown]
# # Parts of Speech (POS) Tagging
#
# The pos (parts of speech) explain you how a word is used in a sentence. In the sentence, a word can have different contexts and semantic meanings. The basic natural language processing (NLP) models like bag-of-words (bow) fails to identify these relations between the words. For that we use POS tagging to mark a word to its POS tag based on its context in the data. POS is also used to extract relationships between the words.

# %%
# importing tokenize library
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# download averaged perceptron tagger
nltk.download('averaged_perceptron_tagger')

# convert text into word tokens with their tags
def pos_tagg(text):
    word_tokens = word_tokenize(text)
    return pos_tag(word_tokens)

# Example usage
pos_tagg("Are you afraid of something?")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/tar-tt060-saurav/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('Are', 'NNP'),
#  ('you', 'PRP'),
#  ('afraid', 'IN'),
#  ('of', 'IN'),
#  ('something', 'NN'),
#  ('?', '.')]

# %% [markdown]
# In the above example, NNP stands for Proper noun, PRP stands for personal noun, IN as Preposition. We can get all the details pos tags using the Penn Treebank tagset.

# %% [markdown]
# ![image.png](attachment:4068bc5a-7d88-419c-8f6d-8f67c330d084.png)
#
#
# ![image.png](attachment:3999231a-25da-4c92-85e4-2fc922bd308d.png)

# %%
#downloading the tagset
nltk.download('tagsets')

#extract information about the tag
nltk.help.upenn_tagset('PRP')
# Out:
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# [nltk_data] Downloading package tagsets to /home/tar-
# [nltk_data]     tt060-saurav/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.

# %% [markdown]
# # Chunking
# Chunking is the process of extracting phrases from the Unstructured text and give them more structure to it. We also called them shallow parsing. We can do it on top of pos tagging. It groups words into chunks mainly for noun phrases. chunking we do by using regular expression.

# %%
# importing libraries
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# here we define chunking function with text and regular
# expressions representing grammar as parameter
def chunking(text, grammar):
  word_tokens = word_tokenize(text)

  # label words with pos
  word_pos = pos_tag(word_tokens)

  # create chunk parser using grammar
  chunkParser = nltk.RegexpParser(grammar)

  # test it on the list of word tokens with tagged pos
  tree = chunkParser.parse(word_pos)

  # iterate over the parse tree and print subtrees
  for subtree in tree.subtrees():
    print(subtree)

# sentence to be chunked
sentence = 'the little red parrot is flying in the sky'

# Regular expression grammar for Noun Phrase (NP)
grammar = "NP: {<DT>?<JJ>*<NN>}"

# Calling the chunking function with the sentence and grammar
chunking(sentence, grammar)
# Out:
# (S
#   (NP the/DT little/JJ red/JJ parrot/NN)
#   is/VBZ
#   flying/VBG
#   in/IN
#   (NP the/DT sky/NN))
# (NP the/DT little/JJ red/JJ parrot/NN)
# (NP the/DT sky/NN)

# %% [markdown]
# ![image.png](attachment:5b992824-b97b-496b-99e7-8b82b38c5d23.png)

# %% [markdown]
# # Named Entity Recognition
#
# IT IS USED TO EXTRACT INFORMATION FROM UNSTRUCTURED TEXT.It is used to classify the entities which are present in the text into categories like a person, organization, event, places, etc. This will give you a detailed knowledge about the text and the relationship between the different entities.

# %%
#Importing tokenization and chunk
from nltk.tokenize import word_tokenize
from nltk import pos_tag, ne_chunk
nltk.download('maxent_ne_chunker')
nltk.download('words')

def ner(text):                    #tokenize the text
  word_tokens = word_tokenize(text)

  #pos tagging of words
  word_pos = pos_tag(word_tokens)

  #tree of word entities
  print(ne_chunk(word_pos))

text = 'Brain Lara scored the highest 400 runs in a test match which played in between WI and England.'
ner(text)
# Out:
# (S
#   (PERSON Brain/NNP)
#   (PERSON Lara/NNP)
#   scored/VBD
#   the/DT
#   highest/JJS
#   400/CD
#   runs/NNS
#   in/IN
#   a/DT
#   test/NN
#   match/NN
#   which/WDT
#   played/VBD
#   in/IN
#   between/IN
#   (ORGANIZATION WI/NNP)
#   and/CC
#   (GPE England/NNP)
#   ./.)
# [nltk_data] Downloading package maxent_ne_chunker to /home/tar-
# [nltk_data]     tt060-saurav/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /home/tar-
# [nltk_data]     tt060-saurav/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# # Understanding Regex
#
# As a software developer, you have probably encountered regular expressions many times and gotten confused many times with these daunting set of characters grouped together like this:

# %% [raw]
# /^\w+([-]?\w)+@\w+([\.]?\w)+(\.[a-zA-Z]{2,3})+$/

# %% [markdown]
# And you may have wondered what this is all about?
#
# Regular Expressions (Regx or RegExp) are very useful in stepping up your algorithm game and this will make you a better problem solver. The structure of RegEx can be intimidating at first, but it is very rewarding once you got all the patterns and implemented them in your work properly.

# %% [markdown]
# # What is RegEx and why is it important?
#
# A Regex or as we call it a regular expression, is a type of object that will help you out to extract information from any string data by searching through text and finding out what you need. Whether it's punctuation, numbers, letters, or even white spaces, RegEx will allow you to check and match any of the character combinations in strings.
#
# For example, suppose you need to match the format of email addresses or security numbers. You can utilize RegEx to check the pattern inside the text strings and use it to replace another substring.
#
# For instance, a RegEx could tell the program to search for the specific text from the string and then print out the output accordingly. Expressions can include text matching, repetition of words, branching, and pattern composition.
#
# ![image.png](attachment:90774887-a126-4e9c-84b1-30cf0685c386.png)

# %% [markdown]
# ![image.png](attachment:80c8b1d3-abee-4c57-8972-1f5e60208df7.png)

# %%
import re

sent = "dataset, Data is a new fuel"
r2 = re.findall(r"^\w+", sent)

print(r2)
# Out:
# ['dataset']

# %% [markdown]
# ![image.png](attachment:ed5464af-89eb-4013-85f4-123c8be146ff.png)

# %% [markdown]
# ## Example of expression in re.split function
#
# "s:" This expression we use for creating a space in the string.
#
# To understand better this expression we will use the split function in a simple example. In this example, we have to split each words using the "re.split"
# function and at the same time we have used is that allows to parse each word in the string seperately.

# %%
import re

sent = "dataset, Data is a new fuel"
r2 = re.findall(r"\w+", sent)  # Find all word characters at the beginning of the string

print(r2)
# Out:
# ['dataset', 'Data', 'is', 'a', 'new', 'fuel']

# %% [markdown]
# # Example of is expression in re.split function
#
# "s:" This expression we use for creating a space in the string.
#
# To understand better this expression we will use the split function in a simple example. In this example, we have to split each words using the "re.split" function and at the same time we have used is that allows to parse each word in the string seperately.

# %%
import re

print((re.split(r'\s', 'We splited this sentence')))
# Out:
# ['We', 'splited', 'this', 'sentence']

# %% [markdown]
# As we can see above we got the output ['We', 'splited', 'this', 'sentence'] but what if we remove '' from 's', it will give result like remove 's' from the entire sentences. Let's see in below example.

# %%
import re

print((re.split(r's', 'We splited this sentence')))
# Out:
# ['We ', 'plited thi', ' ', 'entence']

# %% [markdown]
# Similarly, there are series of regular expression in Python that you can use in various ways like \d,\D,$..,\b, etc.

# %% [markdown]
# # Use RegEx methods
#
#
# The "re" packages provide several methods to actually perform queries on an input string. We will see different methods which are
#
#                            re.match()
#
#                            re.search()
#
#                            re.findall()
#
#
# Note: Based on the RegEx, Python offers two different primitive operations. This match method checks for the match only at the beginning of the string while
# search checks for a match anywhere in the string.
#
# ### Using re.match()
#
# The match function is used to match the RegEx pattern to string with optional flag. Here, in this "w+" and "W" will match the words starting from "i" and
# thereafter anything which is not started with "i" is not identified. For checking match for each element in the list or string, we run the for loop.

# %%
import re

lists = ['icecream images', 'i immitated', 'inner peace']

for i in lists:
    q = re.match("(i\w+)\W(i\w+)", i)

    if q:
        print(q.groups())
# Out:
# ('icecream', 'images')

# %% [markdown]
# # Finding Pattern in the text(re.search())
#
# A RegEx is commonly used to search for a pattern in the text. This method takes a RegEx pattern and a string and searches that pattern with the string.
#
# For using re.search() function, you need to import re first. The search() function takes the "pattern" and "text" to scan from our given string and returns the
# match object when the pattern found or else not match.

# %%
import re

pattern = ["playing", "dataset"]
text = "Raju is playing outside."

for p in pattern:
    print("You're looking for '%s' in '%s'" % (p, text), end='')

    if re.search(p, text):
        print('Found match!')
    else:
        print("no match found!")
# Out:
# You're looking for 'playing' in 'Raju is playing outside.'Found match!
# You're looking for 'dataset' in 'Raju is playing outside.'no match found!

# %% [markdown]
# In the Above example, we look for two literal strings "playing", "iNeuron" and in text string we had taken "Raju is playing outside.". For "playing" we got the match and in the output we got "Found Match", while for the word "iNeuron" we didn't got any match. So, we got no match found for that word.

# %% [markdown]
# # Using re.findall() for text
#
# ![image.png](attachment:ab1cf5ca-4ac9-4179-b4e0-7b4c5bac094a.png)

# %%
import re

kgf = "Abc@gmail.com, XYX@gmail.com, lmn@gmail.com, efg@gmail.com"

emails = re.findall(r' [\w\.]+@[\w\.]+', kgf)

for e in emails:
    print(e)
# Out:
#  XYX@gmail.com
#  lmn@gmail.com
#  efg@gmail.com

# %% [markdown]
# ![image.png](attachment:efb20538-59fa-407f-b107-bb0414ede652.png)
# ![image.png](attachment:d2860c08-9a20-4649-bf12-b475b83f1b60.png)

# %% [markdown]
# ![image.png](attachment:271e9bd7-acf1-4a26-9fb6-cff421ecd1a0.png)

# %% [markdown]
# ![image.png](attachment:37c7f291-434e-4463-a2c2-0677d2fb757e.png)

# %% [markdown]
# # TOKENIZERS
#
# ## NLTK

# %%
# !pip install --user-U nltk

# %%
from nltk.tokenize.regexp import WhitespaceTokenizer

# %%
n="'There is no need to panic. We need to work together, take small yet important measures to ensure self-protect:'"

# %%
from nltk.tokenize import word_tokenize

# %%
text="Founded in 2002, SpaceX's mission is to enable humans to become a spacefaring civilization and a multi-planet species by building a self-sustaining city on Mars. In 2008, SpaceX's Falcon 1 became the first privately developed liquid-fuel launch vehicle to orbit the Earth."

# %%
word_tokenize(text)
# Out:
# ['Founded',
#  'in',
#  '2002',
#  ',',
#  'SpaceX',
#  "'s",
#  'mission',
#  'is',
#  'to',
#  'enable',
#  'humans',
#  'to',
#  'become',
#  'a',
#  'spacefaring',
#  'civilization',
#  'and',
#  'a',
#  'multi-planet',
#  'species',
#  'by',
#  'building',
#  'a',
#  'self-sustaining',
#  'city',
#  'on',
#  'Mars',
#  '.',
#  'In',
#  '2008',
#  ',',
#  'SpaceX',
#  "'s",
#  'Falcon',
#  '1',
#  'became',
#  'the',
#  'first',
#  'privately',
#  'developed',
#  'liquid-fuel',
#  'launch',
#  'vehicle',
#  'to',
#  'orbit',
#  'the',
#  'Earth',
#  '.']

# %% [markdown]
# ![image.png](attachment:92e764a7-34f5-4fed-aae0-1cb19938e63e.png)

# %%
tokens = WhitespaceTokenizer().tokenize(n)
print(len(tokens))
# Out:
# 19

# %%
tokens
# Out:
# ["'There",
#  'is',
#  'no',
#  'need',
#  'to',
#  'panic.',
#  'We',
#  'need',
#  'to',
#  'work',
#  'together,',
#  'take',
#  'small',
#  'yet',
#  'important',
#  'measures',
#  'to',
#  'ensure',
#  "self-protect:'"]

# %%
myvocab = set(tokens)
print(len(tokens))
# Out:
# 19

# %%
myvocab
# Out:
# {"'There",
#  'We',
#  'ensure',
#  'important',
#  'is',
#  'measures',
#  'need',
#  'no',
#  'panic.',
#  "self-protect:'",
#  'small',
#  'take',
#  'to',
#  'together,',
#  'work',
#  'yet'}

# %% [markdown]
# ![image.png](attachment:029a2cec-a44b-4bdf-a78b-52ad14a6feb6.png)

# %%
my_st="There is no need to panic. We need to work together."

# %% [markdown]
# We'll import different tokenizer:

# %%
from nltk.tokenize.regexp import WordPunctTokenizer

# %% [markdown]
# Above tokenizer also split the words into tokens:

# %%
m_t= WordPunctTokenizer().tokenize(my_st)
print(len(m_t))
# Out:
# 13

# %%
m_t
# Out:
# ['There',
#  'is',
#  'no',
#  'need',
#  'to',
#  'panic',
#  '.',
#  'We',
#  'need',
#  'to',
#  'work',
#  'together',
#  '.']

# %% [markdown]
# ![image.png](attachment:5e43f103-98d4-4d32-a3de-430cf654910c.png)

# %%
from nltk.tokenize import sent_tokenize

text = """Founded in 2002, SpaceX's mission is to enable humans to become a spacefaring civilization and a multi-planetary species by building a self-sustaining city on Mars. In 2008, SpaceX's Falcon 1 became the first privately developed liquid-fuel launch vehicle to orbit the Earth."""

sent_tokenize(text)
# Out:
# ["Founded in 2002, SpaceX's mission is to enable humans to become a spacefaring civilization and a multi-planetary species by building a self-sustaining city on Mars.",
#  "In 2008, SpaceX's Falcon 1 became the first privately developed liquid-fuel launch vehicle to orbit the Earth."]

# %% [markdown]
# ![image.png](attachment:18fc01c2-b6d4-4d00-b9d3-d9143046559b.png)

# %%
#from nltk.book import *
import nltk
#nltk.download('gutenberg')

print("\n\n\n")                                                                                                    
text1= "There is no need to panic. We need to work together, take small yet important measures to ensure "

freqDist = nltk. FreqDist(word_tokenize(text1))
print(freqDist)
# Out:
# <FreqDist with 17 samples and 20 outcomes>

# %% [markdown]
# ![image.png](attachment:1cd58287-8b95-4417-b9fd-8fac1710f2a5.png)

# %%
print(freqDist["person"])
# Out:
# 0

# %% [markdown]
# One of the most important function in FreqDist is the .keys() function. Let us see what will it give in a below code.

# %%
words = freqDist.keys()
print(type(words))

words
# Out:
# <class 'dict_keys'>
# dict_keys(['There', 'is', 'no', 'need', 'to', 'panic', '.', 'We', 'work', 'together', ',', 'take', 'small', 'yet', 'important', 'measures', 'ensure'])

# %% [markdown]
# After running above code, it'll give as class 'dict_keys', in the other words, you get a list of all the words in your text.
#
# And you want to see how many words are there in the text

# %%
print(len(words))
# Out:
# 17

# %% [markdown]
# In the class nltk.text. Text function do the same stuff, so what is the difference? The difference is that with FreqDist you can create your own texts without the
# necessity of converting your text to nltk.text. Text class.
#
# And the other usual functon is plot. Plot will do like it displays the most used words in your text. So if you want to see 15 most used words in the text, For
# example like:

# %%
freqDist.plot(15)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # Personal Frequency Distribution
#
#
# Suppose you want to do frequency distribution based on your own personal text. Let's get started,

# %%
from nltk import FreqDist

# %%
from nltk import FreqDist

sent = "There is no need to panic. We need to work together, take small yet important measures to ensure self-protection."

text_list = sent.split(" ")

freqDist = FreqDist(text_list)
words = list(freqDist.keys())

print(freqDist['need'])
# Out:
# 2

# %%
freqDist.plot(15)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ![image.png](attachment:a3505fc5-f55e-403f-ad35-0b600dd8afe4.png)
